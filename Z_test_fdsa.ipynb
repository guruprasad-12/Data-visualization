# %% [markdown]
# <a href="https://colab.research.google.com/github/guruprasad-12/Data-visualization-/blob/main/Z_test_fdsa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statsmodels.stats.weightstats import ztest as ztest

#enter IQ levels for 20 patients
data = [88, 92, 94, 94, 96, 97, 97, 97, 99, 99,
        105, 109, 109, 109, 110, 112, 112, 113, 114, 115]

#perform one sample z-test
p=ztest(data, value=100)
print("The Z-value and the corresponding p-value is:",p)
# Out:
# The Z-value and the corresponding p-value is: (1.5976240527147705, 0.1101266701438426)

# %%
if p[1]<0.05:
  print("Reject Null hypothesis")
else:
  print("Fail to Reject Null hypothesis ")
# Out:
# Fail to Reject Null hypothesis

# %%
#enter IQ levels for 20 individuals from each city
stateA = [82, 84, 85, 89, 91, 91, 92, 94, 99, 99,
         105, 109, 109, 109, 110, 112, 112, 113, 114, 114]

stateB = [90, 91, 91, 91, 95, 95, 99, 99, 108, 109,
         109, 114, 115, 116, 117, 117, 128, 129, 130, 133]

#perform two sample z-test
p=ztest(stateA, stateB, value=0) 
print("The Z-value and the corresponding p-value is:",p)
# Out:
# The Z-value and the corresponding p-value is: (-1.9953236073282115, 0.046007596761332065)

# %%
if p[1]<0.05:
  print("Reject Null hypothesis")
else:
  print("Fail to Reject Null hypothesis ")
# Out:
# Reject Null hypothesis

# %%
# !pip install bioinfokit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bioinfokit.analys import get_data

df = get_data('z_one_samp').data
df.head(2)
# Out:
#       sizes
# 0  4.819289
# 1  3.569358

# %%
df.shape
# Out:
# (50, 1)

# %%
df.describe()
# Out:
#            sizes
# count  50.000000
# mean    5.017959
# std     1.000192
# min     2.776458
# 25%     4.277710
# 50%     4.911968
# 75%     5.856823
# max     6.828167

# %%
df.notnull()
# Out:
#     sizes
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19   True
# 20   True
# 21   True
# 22   True
# 23   True
# 24   True
# 25   True
# 26   True
# 27   True
# 28   True
# 29   True
# 30   True
# 31   True
# 32   True
# 33   True
# 34   True
# 35   True
# 36   True
# 37   True
# 38   True
# 39   True
# 40   True
# 41   True
# 42   True
# 43   True
# 44   True
# 45   True
# 46   True
# 47   True
# 48   True
# 49   True

# %%
df.isnull()
# Out:
#     sizes
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11  False
# 12  False
# 13  False
# 14  False
# 15  False
# 16  False
# 17  False
# 18  False
# 19  False
# 20  False
# 21  False
# 22  False
# 23  False
# 24  False
# 25  False
# 26  False
# 27  False
# 28  False
# 29  False
# 30  False
# 31  False
# 32  False
# 33  False
# 34  False
# 35  False
# 36  False
# 37  False
# 38  False
# 39  False
# 40  False
# 41  False
# 42  False
# 43  False
# 44  False
# 45  False
# 46  False
# 47  False
# 48  False
# 49  False

# %%
from bioinfokit.analys import stat

res = stat()
res.ztest(df=df, x='sizes', mu=5, x_std=0.4, test_type=1)
print(res.summary)
# Out:
# One Sample Z-test
#
# ------------------  ---------
# Sample size         50
# Mean                 5.01796
# Z value              0.317465
# p value (one-tail)   0.375446
# p value (two-tail)   0.750891
# Lower 95.0%          4.90709
# Upper 95.0%          5.12883
# ------------------  ---------

# %%
z, p = res.result[1], res.result[3]
z, p
# Out:
# (0.317464581858033, 0.7508911101410283)

# %%
if p<0.05:
  print("Reject Null hypothesis")
else:
  print("Fail to Reject Null hypothesis ")
# Out:
# Fail to Reject Null hypothesis
